# %%
import pandas as pd

# %%
data=pd.read_csv('data.csv')

# %%
data.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    417566             53278       61360  89.63         67        22807
# 2    539055             52378       60300  88.39         67        22807
# 3    529269             46349       61500  76.42         67        22807
# 4    563215             43594       78256  57.50         67        22744
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  ...  \
# 0               45                1441    01/01/1984        Salaried  ...
# 1               45                1497    24/08/1985   Self employed  ...
# 2               45                1495    09/12/1977   Self employed  ...
# 3               45                1502    01/06/1988        Salaried  ...
# 4               86                1499    14/07/1994   Self employed  ...
#
#   SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  PRIMARY.INSTAL.AMT  \
# ...

# %%
#To check for columns in the data
data.columns
# Out:
# Index(['UniqueID', 'disbursed_amount', 'asset_cost', 'ltv', 'branch_id',
#        'supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Date.of.Birth',
#        'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID',
#        'MobileNo_Avl_Flag', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag',
#        'Driving_flag', 'Passport_flag', 'PERFORM_CNS.SCORE',
#        'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
#        'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
#        'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
#        'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT',
#        'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT',
#        'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
#        'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES',
#        'loan_default'],
#       dtype='object')

# %%
#Desscriptive analyis
data.describe()
# Out:
#             UniqueID  disbursed_amount    asset_cost            ltv  \
# count  233154.000000     233154.000000  2.331540e+05  233154.000000
# mean   535917.573376      54356.993528  7.586507e+04      74.746530
# std     68315.693711      12971.314171  1.894478e+04      11.456636
# min    417428.000000      13320.000000  3.700000e+04      10.030000
# 25%    476786.250000      47145.000000  6.571700e+04      68.880000
# 50%    535978.500000      53803.000000  7.094600e+04      76.800000
# 75%    595039.750000      60413.000000  7.920175e+04      83.670000
# max    671084.000000     990572.000000  1.628992e+06      95.000000
#
#            branch_id    supplier_id  manufacturer_id  Current_pincode_ID  \
# count  233154.000000  233154.000000    233154.000000       233154.000000
# mean       72.936094   19638.635035        69.028054         3396.880247
# std        69.834995    3491.949566        22.141304         2238.147502
# ...

# %%
#Unique values in the data
data.nunique()
# Out:
# UniqueID                               233154
# disbursed_amount                        24565
# asset_cost                              46252
# ltv                                      6579
# branch_id                                  82
# supplier_id                              2953
# manufacturer_id                            11
# Current_pincode_ID                       6698
# Date.of.Birth                           15433
# Employment.Type                             2
# DisbursalDate                              84
# State_ID                                   22
# Employee_code_ID                         3270
# MobileNo_Avl_Flag                           1
# Aadhar_flag                                 2
# PAN_flag                                    2
# VoterID_flag                                2
# Driving_flag                                2
# Passport_flag                               2
# PERFORM_CNS.SCORE                         573
# ...

# %%
#Unique values in the target varables
data ['branch_id'].unique()
# Out:
# array([ 67,  78,  34, 130,  74,  11,   5,  20,  63,  48,  79,   3,  42,
#        142,  36,  16, 146, 147,  65,   9,   1, 152,  29,  10,  70,  19,
#          7,  85,  61,  17,   8, 153,  18, 162,  68,  72,  64,   2, 160,
#        251, 103, 104, 120, 136,  77,  13, 138, 135,  73, 248,  15, 165,
#         62,  76, 105, 249, 250, 255, 254,  82, 158, 159, 117, 202, 259,
#        207,  35,  69,  97,  43, 257, 258, 111,  66, 260, 261, 101,  14,
#        121, 217,  84, 100], dtype=int64)

# %%
#Unique values in the target varables
data['State_ID'].unique()
# Out:
# array([ 6,  4,  3,  9,  5, 10, 18, 15,  1, 16, 13, 14, 17,  2, 11,  7, 12,
#         8, 20, 19, 22, 21], dtype=int64)

# %%
#Unique values in the target varables
data['supplier_id'].unique()
# Out:
# array([22807, 22744, 17014, ..., 23291, 23085, 16270], dtype=int64)

# %%
#Unique values in the target varables
data['manufacturer_id'].unique()
# Out:
# array([ 45,  86,  48,  51,  49, 120, 145,  67, 153, 152, 156], dtype=int64)

# %%
#Unique value counts
data['Employment.Type'].value_counts()
# Out:
# Employment.Type
# Self employed    127635
# Salaried          97858
# Name: count, dtype: int64

# %%
data.columns[5:]
# Out:
# Index(['supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Date.of.Birth',
#        'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID',
#        'MobileNo_Avl_Flag', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag',
#        'Driving_flag', 'Passport_flag', 'PERFORM_CNS.SCORE',
#        'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
#        'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
#        'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
#        'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT',
#        'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT',
#        'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
#        'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES',
#        'loan_default'],
#       dtype='object')

# %%
data['loan_default'].value_counts()
# Out:
# loan_default
# 0    182543
# 1     50611
# Name: count, dtype: int64

# %%
data['Date.of.Birth'].value_counts()
# Out:
# Date.of.Birth
# 01/01/1988    2173
# 01/01/1990    2170
# 01/01/1987    2127
# 01/01/1986    2063
# 01/01/1985    2005
#               ...
# 02/03/1956       1
# 31/01/1970       1
# 21/08/1969       1
# 02/09/1959       1
# 25/08/1962       1
# Name: count, Length: 15433, dtype: int64

# %%
#Missing value columns-wise
data.isna().any()
# Out:
# UniqueID                               False
# disbursed_amount                       False
# asset_cost                             False
# ltv                                    False
# branch_id                              False
# supplier_id                            False
# manufacturer_id                        False
# Current_pincode_ID                     False
# Date.of.Birth                          False
# Employment.Type                         True
# DisbursalDate                          False
# State_ID                               False
# Employee_code_ID                       False
# MobileNo_Avl_Flag                      False
# Aadhar_flag                            False
# PAN_flag                               False
# VoterID_flag                           False
# Driving_flag                           False
# Passport_flag                          False
# PERFORM_CNS.SCORE                      False
# PERFORM_CNS.SCORE.DESCRIPTION          False
# ...

# %%
#Number of missing values column-wisse
data.isna().sum()
# Out:
# UniqueID                                  0
# disbursed_amount                          0
# asset_cost                                0
# ltv                                       0
# branch_id                                 0
# supplier_id                               0
# manufacturer_id                           0
# Current_pincode_ID                        0
# Date.of.Birth                             0
# Employment.Type                        7661
# DisbursalDate                             0
# State_ID                                  0
# Employee_code_ID                          0
# MobileNo_Avl_Flag                         0
# Aadhar_flag                               0
# PAN_flag                                  0
# VoterID_flag                              0
# Driving_flag                              0
# Passport_flag                             0
# PERFORM_CNS.SCORE                         0
# PERFORM_CNS.SCORE.DESCRIPTION             0
# ...

# %%
#Filling Missing values with Zero
data_v1=data.fillna(0)
data_v1.isna().sum()
# Out:
# UniqueID                               0
# disbursed_amount                       0
# asset_cost                             0
# ltv                                    0
# branch_id                              0
# supplier_id                            0
# manufacturer_id                        0
# Current_pincode_ID                     0
# Date.of.Birth                          0
# Employment.Type                        0
# DisbursalDate                          0
# State_ID                               0
# Employee_code_ID                       0
# MobileNo_Avl_Flag                      0
# Aadhar_flag                            0
# PAN_flag                               0
# VoterID_flag                           0
# Driving_flag                           0
# Passport_flag                          0
# PERFORM_CNS.SCORE                      0
# PERFORM_CNS.SCORE.DESCRIPTION          0
# PRI.NO.OF.ACCTS                        0
# PRI.ACTIVE.ACCTS                       0
# ...

# %%
#Also if the filling option wasn't used the drop missing values can also be used,let's say if the missing values were to be dropped
data_v2=data.dropna()
data_v2.isna().sum()
# Out:
# UniqueID                               0
# disbursed_amount                       0
# asset_cost                             0
# ltv                                    0
# branch_id                              0
# supplier_id                            0
# manufacturer_id                        0
# Current_pincode_ID                     0
# Date.of.Birth                          0
# Employment.Type                        0
# DisbursalDate                          0
# State_ID                               0
# Employee_code_ID                       0
# MobileNo_Avl_Flag                      0
# Aadhar_flag                            0
# PAN_flag                               0
# VoterID_flag                           0
# Driving_flag                           0
# Passport_flag                          0
# PERFORM_CNS.SCORE                      0
# PERFORM_CNS.SCORE.DESCRIPTION          0
# PRI.NO.OF.ACCTS                        0
# PRI.ACTIVE.ACCTS                       0
# ...

# %%
#if the shape was to be checked
data_v2.shape
# Out:
# (225493, 41)

# %%
#checking the original shape before dropping missing value
data.shape
# Out:
# (233154, 41)

# %%
#Checking for duplicated values
#There is no duplicates,if there was duplicate then dropping the duplicate could have been an option to treat the issue but no further action action needed
data.duplicated().sum()
# Out:
# 0

# %%
#UNIVARIATE ANALYSIS

# %%
#Target variable distribution
data_v2['loan_default'].value_counts()
# Out:
# loan_default
# 0    176526
# 1     48967
# Name: count, dtype: int64

# %%
#plotting a bar chart
data_v2[['loan_default']].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='loan_default'>

# %%
#plotting a pie chart
data_v2[['loan_default']].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#Target variable distribution
data_v2['Employment.Type'].value_counts()
# Out:
# Employment.Type
# Self employed    127635
# Salaried          97858
# Name: count, dtype: int64

# %%
#plotting a bar chart to check employment type
data_v2[['Employment.Type']].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Employment.Type'>

# %%
#Target variable distribution
data_v2['Date.of.Birth'].value_counts()
# Out:
# Date.of.Birth
# 01/01/1988    2143
# 01/01/1990    2139
# 01/01/1987    2107
# 01/01/1986    2023
# 01/01/1985    1975
#               ...
# 03/07/1962       1
# 15/04/1954       1
# 09/06/1965       1
# 10/12/1955       1
# 25/08/1962       1
# Name: count, Length: 14417, dtype: int64

# %%
#plotting a box plot
data_v2[['Date.of.Birth']].value_counts().plot(kind='box')
# Out:
# <Axes: >

# %%
#BIVARIATE ANALYSIS

# %%
#plotting a scatter plot
data_v2.plot(x='Employment.Type',y='loan_default',kind='scatter')
# Out:
# <Axes: xlabel='Employment.Type', ylabel='loan_default'>

# %%
data_v2.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    417566             53278       61360  89.63         67        22807
# 2    539055             52378       60300  88.39         67        22807
# 3    529269             46349       61500  76.42         67        22807
# 4    563215             43594       78256  57.50         67        22744
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  ...  \
# 0               45                1441    01/01/1984        Salaried  ...
# 1               45                1497    24/08/1985   Self employed  ...
# 2               45                1495    09/12/1977   Self employed  ...
# 3               45                1502    01/06/1988        Salaried  ...
# 4               86                1499    14/07/1994   Self employed  ...
#
#   SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  PRIMARY.INSTAL.AMT  \
# ...

# %%
data.columns[5:]
# Out:
# Index(['supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Date.of.Birth',
#        'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID',
#        'MobileNo_Avl_Flag', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag',
#        'Driving_flag', 'Passport_flag', 'PERFORM_CNS.SCORE',
#        'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
#        'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
#        'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
#        'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT',
#        'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT',
#        'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
#        'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES',
#        'loan_default'],
#       dtype='object')

# %%
#Target variable distribution
data_v2['PRI.ACTIVE.ACCTS'].value_counts()
# Out:
# PRI.ACTIVE.ACCTS
# 0      131395
# 1       41050
# 2       21138
# 3       12044
# 4        7306
# 5        4447
# 6        2741
# 7        1766
# 8        1171
# 9         740
# 10        506
# 11        326
# 12        225
# 13        175
# 14        119
# 15         93
# 17         54
# 16         52
# 18         31
# 19         27
# 20         13
# 24         10
# 22         10
# 23         10
# 21          9
# 26          6
# 25          6
# 28          4
# 27          3
# 31          2
# 35          2
# 34          2
# 37          2
# 32          2
# 42          1
# 43          1
# 39          1
# 65          1
# 52          1
# 144         1
# Name: count, dtype: int64

# %%
#Target variable distribution
data_v2['SEC.ACTIVE.ACCTS'].value_counts()
# Out:
# SEC.ACTIVE.ACCTS
# 0     221737
# 1       2637
# 2        627
# 3        193
# 4        116
# 5         64
# 6         32
# 7         22
# 8         17
# 9         10
# 10         9
# 11         7
# 12         5
# 15         4
# 13         3
# 22         2
# 16         2
# 14         1
# 17         1
# 36         1
# 26         1
# 21         1
# 20         1
# Name: count, dtype: int64

# %%
#Checking loan default for NUMBER OF INQUIRIES less than 1
data_v2[data_v2['NO.OF_INQUIRIES']<1]
# Out:
#         UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0         420825             50578       58400  89.55         67        22807
# 1         417566             53278       61360  89.63         67        22807
# 3         529269             46349       61500  76.42         67        22807
# 4         563215             43594       78256  57.50         67        22744
# 5         498082             73123       92900  79.66         67        22807
# ...          ...               ...         ...    ...        ...          ...
# 233146    532224             69659       85300  83.82        135        23550
# 233148    421689             47349       65502  74.81        202        23389
# 233149    561031             57759       76350  77.28          5        22289
# 233152    442948             22824       40458  61.79        160        16212
# 233153    545300             35299       72698  52.27          3        14573
#
# ...

# %%
#Checking loan default for NUMBER OF INQUIRIES > than 1
data_v2[data_v2['NO.OF_INQUIRIES']>1]
# Out:
#         UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 42        639321             51428       64840  84.82         78        17014
# 148       489620             72468      100243  74.72        130        18758
# 930       652985             51078       71782  72.44         48        24763
# 1040      473461             35439       47600  79.83          3        17038
# 1073      600097             54759       68710  80.77          3        14711
# ...          ...               ...         ...    ...        ...          ...
# 232737    547044             63213       80738  79.27        136        23405
# 232763    571882             61813       73700  84.94        146        21003
# 232857    485300             52603       63706  84.76        136        17783
# 232949    443057             50733       63000  84.92        147        17169
# 232992    532665             52718       79218  71.95        103        21033
#
# ...

# %%
#NO OF INQUIRES VS LOAN DEFAULT ANALYSIS
data_v2.groupby('NO.OF_INQUIRIES')['loan_default'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='NO.OF_INQUIRIES'>

# %%
#LOAN DEFAULT VS NO OF INQUIRIES ANALYSIS
data_v2.groupby('loan_default')['NO.OF_INQUIRIES'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='loan_default'>

# %%
data_v2.boxplot(column='NO.OF_INQUIRIES',by='loan_default')
# Out:
# <Axes: title={'center': 'NO.OF_INQUIRIES'}, xlabel='loan_default'>

# %%
import seaborn as sns

# %%
#A pair plot combines the univariate(single variable analysis) and the bivariate(2 variables comparism) together
#To get all relationship together,we can use the pairplot from seaborn
sns.pairplot(data_v2[['NO.OF_INQUIRIES','branch_id','loan_default']],hue='loan_default')

# %%
data_v2
# Out:
#         UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0         420825             50578       58400  89.55         67        22807
# 1         417566             53278       61360  89.63         67        22807
# 2         539055             52378       60300  88.39         67        22807
# 3         529269             46349       61500  76.42         67        22807
# 4         563215             43594       78256  57.50         67        22744
# ...          ...               ...         ...    ...        ...          ...
# 233149    561031             57759       76350  77.28          5        22289
# 233150    649600             55009       71200  78.72        138        17408
# 233151    603445             58513       68000  88.24        135        23313
# 233152    442948             22824       40458  61.79        160        16212
# 233153    545300             35299       72698  52.27          3        14573
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=data_v2.drop(['NO.OF_INQUIRIES','branch_id','loan_default'],axis=1)

# %%
y=data_v2['loan_default']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (157845, 38) (67648, 38) (157845,) (67648,)

# %%
#Performing logisticRegression
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
#Evaluation on train and test data
from sklearn.metrics import accuracy_score

# %%
train_preds=model.predict
test_preds=model.predict

# %%
train_accuracy=accuracy_score
test_accuracy=accuracy_score

# %%
print('Train_Accuracy:',train_accuracy)
print('Test_Accuracy:',test_accuracy)
# Out:
# Train_Accuracy: <function accuracy_score at 0x0000022861D4C9A0>
# Test_Accuracy: <function accuracy_score at 0x0000022861D4C9A0>
